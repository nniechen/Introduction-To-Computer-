# %% [markdown]
# <a href="https://colab.research.google.com/github/nniechen/Introduction-To-Computer-/blob/main/0304.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# (a) 計算 28 × 16
a = 28 * 16
print("(a) 28 × 16 =", a)

# (b) 計算 3 + 2^3 × (4 + 3)
b = 3 + 2**3 * (4 + 3)
print("(b) 3 + 2^3 × (4 + 3) =", b)
# Out:
# (a) 28 × 16 = 448
# (b) 3 + 2^3 × (4 + 3) = 59
